# %% [markdown]
# <a href="https://colab.research.google.com/github/ibrahim10sy/learn-python/blob/main/projet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***Projet sur l'analyse et visualisation des données***

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
import seaborn as sns

# %%
url = 'https://raw.githubusercontent.com/moncoachdata/MasterClass_DS_ML/main/fandango_scrape.csv'
fandango = pd.read_csv(url)

# %%
fandango.head()
# Out:
#                           FILM  STARS  RATING  VOTES
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846
# 1        Jurassic World (2015)    4.5     4.5  34390
# 2       American Sniper (2015)    5.0     4.8  34085
# 3             Furious 7 (2015)    5.0     4.8  33538
# 4            Inside Out (2015)    4.5     4.5  15749

# %%
fandango.count()
# Out:
# FILM      504
# STARS     504
# RATING    504
# VOTES     504
# dtype: int64

# %%
fandango.columns
# Out:
# Index(['FILM', 'STARS', 'RATING', 'VOTES'], dtype='object')

# %%
fandango.dtypes
# Out:
# FILM       object
# STARS     float64
# RATING    float64
# VOTES       int64
# dtype: object

# %%
fandango.value_counts()
# Out:
# FILM                                       STARS  RATING  VOTES
#  Like Sunday, Like Rain (2015)             4.0    3.7     10       1
# Selam Bahara Yolculuk (2015)               0.0    0.0     0        1
# Six Dance Lessons in Six Weeks (2014)      3.0    3.0     7        1
# Sinister 2 (2015)                          3.5    3.3     973      1
# She's Lost Control (2015)                  5.0    5.0     2        1
#                                                                   ..
# Glass Chin (2015)                          0.0    0.0     0        1
# Girlhood (2015)                            4.0    3.5     10       1
# Gett: The Trial of Viviane Amsalem (2015)  3.5    3.5     59       1
# Get Hard (2015)                            4.0    3.9     5933     1
# Zombeavers (2015)                          4.0    3.8     21       1
# Name: count, Length: 504, dtype: int64

# %%
fandango.shape
# Out:
# (504, 4)

# %%
fandango.index
# Out:
# RangeIndex(start=0, stop=504, step=1)

# %%
# description
fandango.describe()
# Out:
#             STARS      RATING         VOTES
# count  504.000000  504.000000    504.000000
# mean     3.558532    3.375794   1147.863095
# std      1.563133    1.491223   3830.583136
# min      0.000000    0.000000      0.000000
# 25%      3.500000    3.100000      3.000000
# 50%      4.000000    3.800000     18.500000
# 75%      4.500000    4.300000    189.750000
# max      5.000000    5.000000  34846.000000

# %%
# Nuage de point
fig = plt.figure(figsize=(12,4))

sns.scatterplot(data=fandango, y='VOTES',x='RATING',);

# %%
# Calcule de le corrélation entres les features
fandango.drop('FILM', axis=1).corr('pearson')
# Out:
#            STARS    RATING     VOTES
# STARS   1.000000  0.994696  0.164218
# RATING  0.994696  1.000000  0.163764
# VOTES   0.164218  0.163764  1.000000

# %%
fandango['FILM']
# Out:
# 0               Fifty Shades of Grey (2015)
# 1                     Jurassic World (2015)
# 2                    American Sniper (2015)
# 3                          Furious 7 (2015)
# 4                         Inside Out (2015)
#                        ...
# 499                        Valiyavan (2015)
# 500              WWE SummerSlam 2015 (2015)
# 501         Yagavarayinum Naa Kaakka (2015)
# 502    Yesterday, Today and Tomorrow (1964)
# 503                           Zarafa (2012)
# Name: FILM, Length: 504, dtype: object

# %%
fandango['YEAR'] = fandango['FILM'].str.extract(r'\((\d{4})\)')

# %%
fandango['YEAR'] = fandango['YEAR'].astype(int)

# %%
fandango['YEAR'].dtypes
# Out:
# dtype('int64')

# %%
fandango['YEAR']
# Out:
# 0      2015
# 1      2015
# 2      2015
# 3      2015
# 4      2015
#        ...
# 499    2015
# 500    2015
# 501    2015
# 502    1964
# 503    2012
# Name: YEAR, Length: 504, dtype: int64

# %%
y = fandango.value_counts().groupby('YEAR')

# %%
fandango.groupby('YEAR').count()
# Out:
#       FILM  STARS  RATING  VOTES
# YEAR
# 1964     1      1       1      1
# 2012     1      1       1      1
# 2014    24     24      24     24
# 2015   477    477     477    477
# 2016     1      1       1      1

# %%
c = fandango['YEAR'].value_counts()

# %%
c
# Out:
# YEAR
# 2015    477
# 2014     24
# 2016      1
# 1964      1
# 2012      1
# Name: count, dtype: int64

# %%
fig = plt.figure(figsize=(12,4))

# %%
fandango.sort_values(by='VOTES', ascending=False).head(10)
# Out:
#                                                FILM  STARS  RATING  VOTES  \
# 0                       Fifty Shades of Grey (2015)    4.0     3.9  34846
# 1                             Jurassic World (2015)    4.5     4.5  34390
# 2                            American Sniper (2015)    5.0     4.8  34085
# 3                                  Furious 7 (2015)    5.0     4.8  33538
# 4                                 Inside Out (2015)    4.5     4.5  15749
# 5  The Hobbit: The Battle of the Five Armies (2014)    4.5     4.3  15337
# 6               Kingsman: The Secret Service (2015)    4.5     4.2  15205
# 7                                    Minions (2015)    4.0     4.0  14998
# 8                    Avengers: Age of Ultron (2015)    5.0     4.5  14846
# 9                             Into the Woods (2014)    3.5     3.4  13055
#
#    YEAR  COUNTS
# 0  2015     NaN
# 1  2015     NaN
# 2  2015     NaN
# 3  2015     NaN
# 4  2015     NaN
# 5  2014     NaN
# 6  2015     NaN
# ...

# %%
fig = plt.figure(figsize=(12,4))
sns.kdeplot(data=fandango, x='RATING')
# Out:
# <Axes: xlabel='RATING', ylabel='Density'>
