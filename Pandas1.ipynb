# %% [markdown]
# <a href="https://colab.research.google.com/github/ibrahim10sy/learn-python/blob/main/Pandas1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***Series Pandas***

# %%
import numpy as np

# %%
import pandas as pd

# %%
# Documentation de l'objet series
help(pd.Series)
# Out:
# Help on class Series in module pandas.core.series:
#
# class Series(pandas.core.base.IndexOpsMixin, pandas.core.generic.NDFrame)
#  |  Series(data=None, index=None, dtype: 'Dtype | None' = None, name=None, copy: 'bool | None' = None, fastpath: 'bool | lib.NoDefault' = <no_default>) -> 'None'
#  |
#  |  One-dimensional ndarray with axis labels (including time series).
#  |
#  |  Labels need not be unique but must be a hashable type. The object
#  |  supports both integer- and label-based indexing and provides a host of
#  |  methods for performing operations involving the index. Statistical
#  |  methods from ndarray have been overridden to automatically exclude
#  |  missing data (currently represented as NaN).
#  |
#  |  Operations between Series (+, -, /, \*, \*\*) align values based on their
#  |  associated index values-- they need not be the same length. The result
#  |  index will be the sorted union of the two indexes.
#  |
#  |  Parameters
#  |  ----------
# ...

# %%
# Liste de données
my_index = ["USA", "France", "Allemagne","Mali"]

# %%
# Liste des dates
my_data = [1770,1820,1955,1960]

# %%
# Series panda
my_ser = pd.Series(data=my_data, index=my_index)

# %%
my_ser
# Out:
# USA          1770
# France       1820
# Allemagne    1955
# Mali         1960
# dtype: int64

# %%
# Indexation
my_ser['USA']
# Out:
# 1770

# %%
# Dictionnaire
age = {"Ibrahim":20, "Madou": 12, "Chaka":23}
pd.Series(age)
# Out:
# Ibrahim    20
# Madou      12
# Chaka      23
# dtype: int64

# %%
# Données de vente inventé
q1 = {'Japan': 80, 'China': 450, 'India': 200, 'USA': 250}
q2 = {'Brazil': 100,'China': 500, 'India': 210,'USA':100}

# %%
sales_q1 = pd.Series(q1)
sales_q2 = pd.Series(q2)

# %%
sales_q1
# Out:
# Japan     80
# China    450
# India    200
# USA      250
# dtype: int64

# %%
# Indexation
sales_q1[0]
# Out:
# <ipython-input-20-09b4c6a29c64>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sales_q1[0]
# 80

# %%
sales_q1['China']
# Out:
# 450

# %%
# Clés de la serie
sales_q1.keys()
# Out:
# Index(['Japan', 'China', 'India', 'USA'], dtype='object')

# %%
arr = np.array([1,2,3])

# %%
arr1 = arr *2
arr1
# Out:
# array([2, 4, 6])

# %%
sales_q2 / 100
# Out:
# Brazil    1.0
# China     5.0
# India     2.1
# USA       1.0
# dtype: float64

# %%
sales_q1 + sales_q2
# Out:
# Brazil      NaN
# China     950.0
# India     410.0
# Japan       NaN
# USA       350.0
# dtype: float64

# %%
sales_q1.add(other=sales_q2, fill_value=1)
# Out:
# Brazil    101.0
# China     950.0
# India     410.0
# Japan      81.0
# USA       350.0
# dtype: float64

# %%
sales_q1.add(other=sales_q2, fill_value=0)
# Out:
# Brazil    100.0
# China     950.0
# India     410.0
# Japan      80.0
# USA       350.0
# dtype: float64

# %%
# Type de données
sales_q1.dtype
# Out:
# dtype('int64')

# %%
first_type= sales_q1.add(other=sales_q2, fill_value=0)

# %%
first_type.dtype
# Out:
# dtype('float64')

# %% [markdown]
# # ***DataFrame pandas***

# %%
# Nombrea aléatoir avec la methode seed
np.random.seed(101)
# Création d'un tableau de données aléatoire
my_data = np.random.randint(0,101,(4,3))

# %%
my_data
# Out:
# array([[95, 11, 81],
#        [70, 63, 87],
#        [75,  9, 77],
#        [40,  4, 63]])

# %%
# création de l'index
my_index = ['CA', 'NY', 'AZ', 'TX']

# %%
# colonne
my_columns = ['Jan', 'Feb', 'Mar']

# %%
# création du dataFrame
df = pd.DataFrame(my_data)

# %%
# Affichage du dataframe
df
# Out:
#     0   1   2
# 0  95  11  81
# 1  70  63  87
# 2  75   9  77
# 3  40   4  63

# %%
# @title 1

from matplotlib import pyplot as plt
df[1].plot(kind='hist', bins=20, title=1)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df_data = pd.DataFrame(data=my_data, index=my_index, columns=my_columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-7bc783795aa5> in <cell line: 1>()
# ----> 1 df_data = pd.DataFrame(data=my_data, index=my_index, columns=my_columns)
#
# NameError: name 'pd' is not defined

# %%
df_data
# Out:
#     Jan  Feb  Mar
# CA   95   11   81
# NY   70   63   87
# AZ   75    9   77
# TX   40    4   63

# %%
# Info sur le dataframe
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, CA to TX
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Jan     4 non-null      int64
#  1   Feb     4 non-null      int64
#  2   Mar     4 non-null      int64
# dtypes: int64(3)
# memory usage: 300.0+ bytes

# %%
ls
# Out:
# '23 - assets.csv'   dataset_244_lignes.csv   sample_data/   tips.csv

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/tips.csv')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0       49.59  5.76  Female     No   Sat   Lunch     1             49.59
# 1       44.84  1.36  Female    Yes  Thur  Dinner     2             22.42
# 2       44.09  4.15    Male     No  Thur   Lunch     5              8.82
# 3       43.73  8.10  Female     No   Fri  Dinner     1             43.73
# 4       14.64  5.38    Male     No   Sat   Lunch     6              2.44
#
#          Payer Name         CC Number Payment ID
# 0     Michael Avila  1900150430370796    Sat9766
# 1      Tonya Carter  9662633192418041   Thur8155
# 2        Keith Wong  8931077392011890   Thur3955
# 3  Nathaniel Harris  7537214471119914    Fri9117
# 4      Tonya Carter  6707651664586514    Sat9462

# %%
col = df.columns
col
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')

# %%
df.keys()
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %%
# Affichage des 3 derniers lignes
df.tail(3)
# Out:
#      total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 241       31.06  8.02  Female    Yes  Sun  Dinner     4              7.76
# 242       18.12  8.12  Female     No  Sun   Lunch     3              6.04
# 243       22.50  3.84    Male     No  Fri   Lunch     1             22.50
#
#          Payer Name         CC Number Payment ID
# 241  Monica Sanders  5885372770415014    Sun1633
# 242      Keith Wong   949194541098695    Sun2552
# 243  Travis Walters  5399041384021608    Fri9944

# %%
# description du dataset
df.describe()
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    30.519385    5.391680    3.323770         13.129959  4.939446e+15
# std     11.468785    2.649527    1.624684         11.036114  2.800545e+15
# min     10.020000    1.000000    1.000000          1.700000  1.246680e+14
# 25%     20.102500    3.167500    2.000000          5.747500  2.636416e+15
# 50%     29.015000    5.390000    3.000000          9.040000  5.211561e+15
# 75%     40.650000    7.767500    5.000000         16.100000  7.004865e+15
# max     49.950000    9.990000    6.000000         49.590000  9.976659e+15

# %%
# Description par transposition
df.describe().transpose()
# Out:
#                   count          mean           std           min  \
# total_bill        244.0  3.051939e+01  1.146878e+01  1.002000e+01
# tip               244.0  5.391680e+00  2.649527e+00  1.000000e+00
# size              244.0  3.323770e+00  1.624684e+00  1.000000e+00
# price_per_person  244.0  1.312996e+01  1.103611e+01  1.700000e+00
# CC Number         244.0  4.939446e+15  2.800545e+15  1.246680e+14
#
#                            25%           50%           75%           max
# total_bill        2.010250e+01  2.901500e+01  4.065000e+01  4.995000e+01
# tip               3.167500e+00  5.390000e+00  7.767500e+00  9.990000e+00
# size              2.000000e+00  3.000000e+00  5.000000e+00  6.000000e+00
# price_per_person  5.747500e+00  9.040000e+00  1.610000e+01  4.959000e+01
# CC Number         2.636416e+15  5.211561e+15  7.004865e+15  9.976659e+15

# %% [markdown]
# # ***Opération sur les dataFrames***

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0       49.59  5.76  Female     No   Sat   Lunch     1             49.59
# 1       44.84  1.36  Female    Yes  Thur  Dinner     2             22.42
# 2       44.09  4.15    Male     No  Thur   Lunch     5              8.82
# 3       43.73  8.10  Female     No   Fri  Dinner     1             43.73
# 4       14.64  5.38    Male     No   Sat   Lunch     6              2.44
#
#          Payer Name         CC Number Payment ID
# 0     Michael Avila  1900150430370796    Sat9766
# 1      Tonya Carter  9662633192418041   Thur8155
# 2        Keith Wong  8931077392011890   Thur3955
# 3  Nathaniel Harris  7537214471119914    Fri9117
# 4      Tonya Carter  6707651664586514    Sat9462

# %%
# Indexation
df['total_bill']
# Out:
# 0      49.59
# 1      44.84
# 2      44.09
# 3      43.73
# 4      14.64
#        ...
# 239    48.48
# 240    47.14
# 241    31.06
# 242    18.12
# 243    22.50
# Name: total_bill, Length: 244, dtype: float64

# %%
# Multi-selection
col = ['total_bill', 'price_per_person']
df[col].head()
# Out:
#    total_bill  price_per_person
# 0       49.59             49.59
# 1       44.84             22.42
# 2       44.09              8.82
# 3       43.73             43.73
# 4       14.64              2.44

# %%
df['pour_tip'] = 100 *df['tip'] / df['total_bill']

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0       49.59  5.76  Female     No   Sat   Lunch     1             49.59
# 1       44.84  1.36  Female    Yes  Thur  Dinner     2             22.42
# 2       44.09  4.15    Male     No  Thur   Lunch     5              8.82
# 3       43.73  8.10  Female     No   Fri  Dinner     1             43.73
# 4       14.64  5.38    Male     No   Sat   Lunch     6              2.44
#
#          Payer Name         CC Number Payment ID   pour_tip
# 0     Michael Avila  1900150430370796    Sat9766  11.615245
# 1      Tonya Carter  9662633192418041   Thur8155   3.033006
# 2        Keith Wong  8931077392011890   Thur3955   9.412565
# 3  Nathaniel Harris  7537214471119914    Fri9117  18.522753
# 4      Tonya Carter  6707651664586514    Sat9462  36.748634

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df.tail(3)
# Out:
#      total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 241       31.06  8.02  Female    Yes  Sun  Dinner     4              7.76
# 242       18.12  8.12  Female     No  Sun   Lunch     3              6.04
# 243       22.50  3.84    Male     No  Fri   Lunch     1             22.50
#
#          Payer Name         CC Number Payment ID
# 241  Monica Sanders  5885372770415014    Sun1633
# 242      Keith Wong   949194541098695    Sun2552
# 243  Travis Walters  5399041384021608    Fri9944

# %%
# info sur le dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %%
df.describe()
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    30.519385    5.391680    3.323770         13.129959  4.939446e+15
# std     11.468785    2.649527    1.624684         11.036114  2.800545e+15
# min     10.020000    1.000000    1.000000          1.700000  1.246680e+14
# 25%     20.102500    3.167500    2.000000          5.747500  2.636416e+15
# 50%     29.015000    5.390000    3.000000          9.040000  5.211561e+15
# 75%     40.650000    7.767500    5.000000         16.100000  7.004865e+15
# max     49.950000    9.990000    6.000000         49.590000  9.976659e+15

# %%
df.describe().transpose()
# Out:
#                   count          mean           std           min  \
# total_bill        244.0  3.051939e+01  1.146878e+01  1.002000e+01
# tip               244.0  5.391680e+00  2.649527e+00  1.000000e+00
# size              244.0  3.323770e+00  1.624684e+00  1.000000e+00
# price_per_person  244.0  1.312996e+01  1.103611e+01  1.700000e+00
# CC Number         244.0  4.939446e+15  2.800545e+15  1.246680e+14
#
#                            25%           50%           75%           max
# total_bill        2.010250e+01  2.901500e+01  4.065000e+01  4.995000e+01
# tip               3.167500e+00  5.390000e+00  7.767500e+00  9.990000e+00
# size              2.000000e+00  3.000000e+00  5.000000e+00  6.000000e+00
# price_per_person  5.747500e+00  9.040000e+00  1.610000e+01  4.959000e+01
# CC Number         2.636416e+15  5.211561e+15  7.004865e+15  9.976659e+15

# %%
df['pour_per'] = np.round(100 * df['tip'] / df['total_bill'], 2)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0       49.59  5.76  Female     No   Sat   Lunch     1             49.59
# 1       44.84  1.36  Female    Yes  Thur  Dinner     2             22.42
# 2       44.09  4.15    Male     No  Thur   Lunch     5              8.82
# 3       43.73  8.10  Female     No   Fri  Dinner     1             43.73
# 4       14.64  5.38    Male     No   Sat   Lunch     6              2.44
#
#          Payer Name         CC Number Payment ID  pour_per
# 0     Michael Avila  1900150430370796    Sat9766     11.62
# 1      Tonya Carter  9662633192418041   Thur8155      3.03
# 2        Keith Wong  8931077392011890   Thur3955      9.41
# 3  Nathaniel Harris  7537214471119914    Fri9117     18.52
# 4      Tonya Carter  6707651664586514    Sat9462     36.75

# %%
# supprimer une colonne
df = df.drop('pour_per', axis=1)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         49.59  5.76  Female     No   Sat   Lunch     1             49.59
# 1         44.84  1.36  Female    Yes  Thur  Dinner     2             22.42
# 2         44.09  4.15    Male     No  Thur   Lunch     5              8.82
# 3         43.73  8.10  Female     No   Fri  Dinner     1             43.73
# 4         14.64  5.38    Male     No   Sat   Lunch     6              2.44
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       48.48  3.59    Male     No   Fri   Lunch     3             16.16
# 240       47.14  8.75  Female    Yes   Sun   Lunch     6              7.86
# 241       31.06  8.02  Female    Yes   Sun  Dinner     4              7.76
# 242       18.12  8.12  Female     No   Sun   Lunch     3              6.04
# 243       22.50  3.84    Male     No   Fri   Lunch     1             22.50
#
#            Payer Name         CC Number Payment ID
# ...

# %%
# @title price_per_person

from matplotlib import pyplot as plt
df['price_per_person'].plot(kind='line', figsize=(8, 4), title='price_per_person')
plt.gca().spines[['top', 'right']].set_visible(True)

# %%
df.shape
# Out:
# (244, 11)
