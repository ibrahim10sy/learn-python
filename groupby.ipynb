# %% [markdown]
# <a href="https://colab.research.google.com/github/ibrahim10sy/learn-python/blob/main/groupby.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import pandas as pd

# %%
import random

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/tips.csv')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0       49.59  5.76  Female     No   Sat   Lunch     1             49.59
# 1       44.84  1.36  Female    Yes  Thur  Dinner     2             22.42
# 2       44.09  4.15    Male     No  Thur   Lunch     5              8.82
# 3       43.73  8.10  Female     No   Fri  Dinner     1             43.73
# 4       14.64  5.38    Male     No   Sat   Lunch     6              2.44
#
#          Payer Name         CC Number Payment ID
# 0     Michael Avila  1900150430370796    Sat9766
# 1      Tonya Carter  9662633192418041   Thur8155
# 2        Keith Wong  8931077392011890   Thur3955
# 3  Nathaniel Harris  7537214471119914    Fri9117
# 4      Tonya Carter  6707651664586514    Sat9462

# %%
gp = df.groupby(['total_bill','tip'])

# %%
gp.idxmax()
# Out:
#                  sex  smoker  day  time  size  price_per_person  Payer Name  \
# total_bill tip
# 10.02      6.10  123     123  123   123   123               123         123
# 10.17      8.25  182     182  182   182   182               182         182
# 10.22      7.89  222     222  222   222   222               222         222
# 10.27      2.49  158     158  158   158   158               158         158
# 10.35      5.44  144     144  144   144   144               144         144
# ...              ...     ...  ...   ...   ...               ...         ...
# 49.07      4.94  101     101  101   101   101               101         101
# 49.58      1.02  131     131  131   131   131               131         131
# 49.59      5.76    0       0    0     0     0                 0           0
# 49.90      6.24   42      42   42    42    42                42          42
# 49.95      7.52   56      56   56    56    56                56          56
#
#                  CC Number  Payment ID
# total_bill tip
# 10.02      6.10        123         123
# 10.17      8.25        182         182
# 10.22      7.89        222         222
# 10.27      2.49        158         158
# 10.35      5.44        144         144
# ...                    ...         ...
# 49.07      4.94        101         101
# 49.58      1.02        131         131
# 49.59      5.76          0           0
# 49.90      6.24         42          42
# 49.95      7.52         56          56
#
# [244 rows x 9 columns]

# %%
mp = df.groupby(['total_bill','tip'])['tip'].mean()

# %%
mp
# Out:
# total_bill  tip
# 10.02       6.10    6.10
# 10.17       8.25    8.25
# 10.22       7.89    7.89
# 10.27       2.49    2.49
# 10.35       5.44    5.44
#                     ...
# 49.07       4.94    4.94
# 49.58       1.02    1.02
# 49.59       5.76    5.76
# 49.90       6.24    6.24
# 49.95       7.52    7.52
# Name: tip, Length: 244, dtype: float64

# %%
r = df.iloc[[0,1]]

# %%
r
# Out:
#    total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0       49.59  5.76  Female     No   Sat   Lunch     1             49.59
# 1       44.84  1.36  Female    Yes  Thur  Dinner     2             22.42
#
#       Payer Name         CC Number Payment ID
# 0  Michael Avila  1900150430370796    Sat9766
# 1   Tonya Carter  9662633192418041   Thur8155

# %%
df_copy = df.copy

# %%
df.value_counts()
# Out:
# total_bill  tip   sex     smoker  day   time    size  price_per_person  Payer Name          CC Number         Payment ID
# 10.02       6.10  Male    No      Thur  Dinner  5     2.00              Michelle Hardin     7440002588079173  Thur7383      1
# 34.98       6.94  Male    No      Sun   Dinner  2     17.49             Christy Cunningham  4389846252452594  Sun7851       1
# 35.37       1.32  Male    Yes     Sat   Lunch   3     11.79             Nathaniel Harris    1070677629439924  Sat2711       1
# 35.80       8.56  Male    Yes     Fri   Dinner  5     7.16              Douglas Tucker      6519136955630471  Fri3347       1
# 35.96       3.51  Female  Yes     Sun   Dinner  5     7.19              Monica Sanders      833449763338560   Sun3396       1
#                                                                                                                            ..
# 24.29       7.79  Male    No      Sat   Dinner  1     24.29             Michelle Hardin     1428008696651119  Sat2916       1
# 24.69       4.64  Male    No      Sun   Lunch   5     4.94              Douglas Tucker      3704245810208080  Sun8969       1
# 24.87       3.17  Female  No      Thur  Dinner  3     8.29              Douglas Tucker      5096947325127258  Thur4341      1
# 24.96       7.24  Female  No      Sun   Lunch   4     6.24              Travis Walters      8583801228439678  Sun6182       1
# 49.95       7.52  Female  Yes     Sat   Lunch   2     24.98             Michelle Hardin     5667170515352102  Sat4594       1
# Name: count, Length: 244, dtype: int64

# %%
df.loc[[0,1]]
# Out:
#    total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0       49.59  5.76  Female     No   Sat   Lunch     1             49.59
# 1       44.84  1.36  Female    Yes  Thur  Dinner     2             22.42
#
#       Payer Name         CC Number Payment ID
# 0  Michael Avila  1900150430370796    Sat9766
# 1   Tonya Carter  9662633192418041   Thur8155

# %%
df[df['size'].isin([2,4])].groupby(['total_bill'])

# %%
m = df[['total_bill','tip','price_per_person']]

# %%
m.agg(['std','mean','max','min'])
# Out:
#       total_bill       tip  price_per_person
# std    11.468785  2.649527         11.036114
# mean   30.519385  5.391680         13.129959
# max    49.950000  9.990000         49.590000
# min    10.020000  1.000000          1.700000

# %%
m.agg({'total_bill':['max','min','std'], 'tip':['min','max','mean']}).transpose()
# Out:
#               max    min        std     mean
# total_bill  49.95  10.02  11.468785      NaN
# tip          9.99   1.00        NaN  5.39168
