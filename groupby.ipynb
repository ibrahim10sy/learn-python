# %% [markdown]
# <a href="https://colab.research.google.com/github/ibrahim10sy/learn-python/blob/main/groupby.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import pandas as pd

# %%
import random

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/tips.csv')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0       49.59  5.76  Female     No   Sat   Lunch     1             49.59
# 1       44.84  1.36  Female    Yes  Thur  Dinner     2             22.42
# 2       44.09  4.15    Male     No  Thur   Lunch     5              8.82
# 3       43.73  8.10  Female     No   Fri  Dinner     1             43.73
# 4       14.64  5.38    Male     No   Sat   Lunch     6              2.44
#
#          Payer Name         CC Number Payment ID
# 0     Michael Avila  1900150430370796    Sat9766
# 1      Tonya Carter  9662633192418041   Thur8155
# 2        Keith Wong  8931077392011890   Thur3955
# 3  Nathaniel Harris  7537214471119914    Fri9117
# 4      Tonya Carter  6707651664586514    Sat9462

# %%
df.groupby(['total_bill','tip'])['Payer Name']

# %%
df.groupby(['total_bill','tip']).mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in _agg_py_fallback(self, how, values, ndim, alt)
#    1941         try:
# -> 1942             res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943         except Exception as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func, preserve_dtype)
#     863
# --> 864         result = self._aggregate_series_pure_python(obj, func)
#     865
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in _aggregate_series_pure_python(self, obj, func)
#     884         for i, group in enumerate(splitter):
# --> 885             res = func(group)
#     886             res = extract_result(res)
#
# ...
