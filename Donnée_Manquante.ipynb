# %% [markdown]
# <a href="https://colab.research.google.com/github/ibrahim10sy/learn-python/blob/main/Donn%C3%A9e_Manquante.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***Gestion des données manquante***

# %%
import numpy as np

# %%
import pandas as pd

# %%
data = {
    "first_name": ["Tom", np.nan, "Hugh", "Oprah", "Emma"],
    "last_name": ["Hanks", np.nan, "Jackman", "Winfrey", "Stone"],
    "age": [63.0, np.nan, 51.0, 66.0, 31.0],
    "sex": ["m", np.nan, "m", "f", "f"],
    "pre_movie_score": [8.0, np.nan, np.nan, 6.0, 7.0],
    "post_movie_score": [10.0, np.nan, np.nan, 8.0, 9.0]
}

df = pd.DataFrame(data)

# %%
df.head()
# Out:
#   first_name last_name   age  sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0    m              8.0              10.0
# 1        NaN       NaN   NaN  NaN              NaN               NaN
# 2       Hugh   Jackman  51.0    m              NaN               NaN
# 3      Oprah   Winfrey  66.0    f              6.0               8.0
# 4       Emma     Stone  31.0    f              7.0               9.0

# %%
# vérification des valeurs null
df.isnull()
# Out:
#    first_name  last_name    age    sex  pre_movie_score  post_movie_score
# 0       False      False  False  False            False             False
# 1        True       True   True   True             True              True
# 2       False      False  False  False             True              True
# 3       False      False  False  False            False             False
# 4       False      False  False  False            False             False

# %%
# vérification des valeurs non null
df.notnull()
# Out:
#    first_name  last_name    age    sex  pre_movie_score  post_movie_score
# 0        True       True   True   True             True              True
# 1       False      False  False  False            False             False
# 2        True       True   True   True            False             False
# 3        True       True   True   True             True              True
# 4        True       True   True   True             True              True

# %%
df[df['first_name'] == 'Tom']
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0   m              8.0              10.0

# %%
df[(df['pre_movie_score'].isnull()) & (df['first_name']).notnull()]
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score
# 2       Hugh   Jackman  51.0   m              NaN               NaN

# %%
df = df.rename(columns={"sex":"sexe"}, inplace=True)

# %%
df.dtypes
# Out:
# first_name           object
# last_name            object
# age                 float64
# sex                  object
# pre_movie_score     float64
# post_movie_score    float64
# dtype: object

# %%
 a = df['age'] > 65
 s = df['sexe'] == 'm'

# %%
df[a & s]
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score sexe
# 3      Oprah   Winfrey  66.0   f              6.0               8.0    m

# %%
 ag = df['age'].iloc[0]

# %%
ag
# Out:
# 63.0

# %%
str(ag)[1:]
# Out:
# '3.0'

# %%
help(df.dropna)
# Out:
# Help on method dropna in module pandas.core.frame:
#
# dropna(*, axis: 'Axis' = 0, how: 'AnyAll | lib.NoDefault' = <no_default>, thresh: 'int | lib.NoDefault' = <no_default>, subset: 'IndexLabel | None' = None, inplace: 'bool' = False, ignore_index: 'bool' = False) -> 'DataFrame | None' method of pandas.core.frame.DataFrame instance
#     Remove missing values.
#
#     See the :ref:`User Guide <missing_data>` for more on which values are
#     considered missing, and how to work with missing data.
#
#     Parameters
#     ----------
#     axis : {0 or 'index', 1 or 'columns'}, default 0
#         Determine if rows or columns which contain missing values are
#         removed.
#
#         * 0, or 'index' : Drop rows which contain missing values.
#         * 1, or 'columns' : Drop columns which contain missing value.
#
#         Only a single axis is allowed.
#
#     how : {'any', 'all'}, default 'any'
#         Determine if row or column is removed from DataFrame, when we have
# ...

# %%
df.head()
# Out:
#   first_name last_name   age  sex  pre_movie_score  post_movie_score sexe
# 0        Tom     Hanks  63.0    m              8.0              10.0    m
# 1        NaN       NaN   NaN  NaN              NaN               NaN    m
# 2       Hugh   Jackman  51.0    m              NaN               NaN    m
# 3      Oprah   Winfrey  66.0    f              6.0               8.0    m
# 4       Emma     Stone  31.0    f              7.0               9.0    m

# %%
# supprimer les lignes ayant moins de 4 valeurs non null
df.dropna(thresh=4)
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score sexe
# 0        Tom     Hanks  63.0   m              8.0              10.0    m
# 2       Hugh   Jackman  51.0   m              NaN               NaN    m
# 3      Oprah   Winfrey  66.0   f              6.0               8.0    m
# 4       Emma     Stone  31.0   f              7.0               9.0    m

# %%
# supprimer toute les vauleurs null
df.dropna()
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score sexe
# 0        Tom     Hanks  63.0   m              8.0              10.0    m
# 3      Oprah   Winfrey  66.0   f              6.0               8.0    m
# 4       Emma     Stone  31.0   f              7.0               9.0    m

# %%
# avec les colonnes spécifique
df.dropna(subset=['sexe','age' ])
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score sexe
# 0        Tom     Hanks  63.0   m              8.0              10.0    m
# 2       Hugh   Jackman  51.0   m              NaN               NaN    m
# 3      Oprah   Winfrey  66.0   f              6.0               8.0    m
# 4       Emma     Stone  31.0   f              7.0               9.0    m

# %%
# fillna permet de remplacer toutes les valeurs manquantes
# df.fillna('null!')
# Out:
#   first_name last_name    age    sex pre_movie_score post_movie_score sexe
# 0        Tom     Hanks   63.0      m             8.0             10.0    m
# 1      null!     null!  null!  null!           null!            null!    m
# 2       Hugh   Jackman   51.0      m           null!            null!    m
# 3      Oprah   Winfrey   66.0      f             6.0              8.0    m
# 4       Emma     Stone   31.0      f             7.0              9.0    m

# %%
df['age'].fillna(0)
# Out:
# 0    63.0
# 1     0.0
# 2    51.0
# 3    66.0
# 4    31.0
# Name: age, dtype: float64

# %%
df['pre_movie_score'] = df['pre_movie_score'].fillna(df['pre_movie_score'].mean())

# %%
df.head()
# Out:
#   first_name last_name   age  sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0    m              8.0              10.0
# 1        NaN       NaN   NaN  NaN              7.0               NaN
# 2       Hugh   Jackman  51.0    m              7.0               NaN
# 3      Oprah   Winfrey  66.0    f              6.0               8.0
# 4       Emma     Stone  31.0    f              7.0               9.0

# %%
 df.interpolate()
# Out:
# <ipython-input-58-11c47216a02d>:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate()
#   first_name last_name   age  sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0    m         8.000000         10.000000
# 1        NaN       NaN  57.0  NaN         7.333333          9.333333
# 2       Hugh   Jackman  51.0    m         6.666667          8.666667
# 3      Oprah   Winfrey  66.0    f         6.000000          8.000000
# 4       Emma     Stone  31.0    f         7.000000          9.000000
